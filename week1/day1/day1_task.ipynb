# %%
df=[
    (1, 100, "2024-01-01"),
    (2, None, "2024-01-02"),
    (3, 300, None)
    ]
df = spark.createDataFrame(df, ["ID", "amount", "JoinDate"])
df.show()
# Out:
# +---+------+----------+
# | ID|amount|  JoinDate|
# +---+------+----------+
# |  1|   100|2024-01-01|
# |  2|  NULL|2024-01-02|
# |  3|   300|      NULL|
# +---+------+----------+

# %%
df.printSchema()
# Out:
# root
#  |-- ID: long (nullable = false)
#  |-- amount: long (nullable = false)
#  |-- JoinDate: string (nullable = true)

# %%
df=df.fillna(0)
df.show()
# Out:
# +---+------+----------+
# | ID|amount|  JoinDate|
# +---+------+----------+
# |  1|   100|2024-01-01|
# |  2|     0|2024-01-02|
# |  3|   300|      NULL|
# +---+------+----------+
